# %%
print("Hello World")
# Out:
# Hello World

# %%
from ScraperFC import FBref
fbref = FBref()

# %%
liga_mx_df = fbref.scrape_matches(year="2025-2026", league="Liga MX")
# Out:
# 2025-2026 Liga MX matches: 100%|██████████| 62/62 [08:14<00:00,  7.98s/it]

# %%
print(liga_mx_df.head())
# Out:
#                                                 Link                    Date  \
# 0  https://fbref.com/en/matches/66dfeb1b/Necaxa-L...  Friday August 15, 2025
# 1  https://fbref.com/en/matches/5590d6c7/Puebla-A...  Friday August 15, 2025
# 2  https://fbref.com/en/matches/0d4c1bf2/Tijuana-...  Friday August 22, 2025
# 3  https://fbref.com/en/matches/d55c5a9b/FC-Juare...  Friday August 22, 2025
# 4  https://fbref.com/en/matches/3700b285/Queretar...  Friday August 22, 2025
#
#                                     Stage  Home Team      Away Team  \
# 0  Liga MX (Apertura 2025 Regular Season)     Necaxa           León
# 1  Liga MX (Apertura 2025 Regular Season)     Puebla       Atlético
# 2  Liga MX (Apertura 2025 Regular Season)    Tijuana    Guadalajara
# 3  Liga MX (Apertura 2025 Regular Season)  FC Juárez  Santos Laguna
# 4  Liga MX (Apertura 2025 Regular Season)  Querétaro       Atlético
#
#   Home Team ID Away Team ID Home Goals Away Goals  \
# 0     752db496     fd7dad55          0          1
# 1     73fd2313     5d274ee4          0          2
# 2     a42ddf2f     c02b0f7a          3          3
# 3     29bff345     03b65ba9          2          1
# 4     c3352ce7     5d274ee4          3          2
#
#                                    Home Player Stats  \
# 0  Summary                 Unnamed: 0_level_0 Unn...
# 1  Summary                  Unnamed: 0_level_0 Un...
# 2  Summary                  Unnamed: 0_level_0 Un...
# 3  Summary               Unnamed: 0_level_0 Unnam...
# 4  Summary                     Unnamed: 0_level_0...
#
#                                    Away Player Stats  \
# 0  Summary              Unnamed: 0_level_0 Unname...
# 1  Summary                    Unnamed: 0_level_0 ...
# 2  Summary               Unnamed: 0_level_0 Unnam...
# 3  Summary               Unnamed: 0_level_0 Unnam...
# 4  Summary                    Unnamed: 0_level_0 ...
#
#                                                Shots
# 0  Both       Unnamed: 0_level_0     Unnamed: 1_l...
# 1  Both       Unnamed: 0_level_0        Unnamed: ...
# 2  Both       Unnamed: 0_level_0     Unnamed: 1_l...
# 3  Both       Unnamed: 0_level_0   Unnamed: 1_lev...
# 4  Both       Unnamed: 0_level_0          Unnamed...
